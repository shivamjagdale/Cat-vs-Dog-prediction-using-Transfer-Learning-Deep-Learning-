# %%
# Cat vs Dog prediction using Transfer Learning (Deep Learning)

# Here we are about 25,000 images of cat and dog and we will process them and when you give a new image it should tell you if that image is cat or dog. 
# Here we are using Transfer Learning and the pretrained model which we are using is called Mobile_net_v2. 

# The prediction we got for our model is 97% meaning for 100 images our model can predict correctly 97 images and tell us if that image is dog or cat. 
# For some reason if you can't see the file or it shows some error download the file.

# %%
# configuring the path of Kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# getting the dataset
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Downloading dogs-vs-cats.zip to /content
#  99% 804M/812M [00:10<00:00, 133MB/s]
# 100% 812M/812M [00:10<00:00, 82.4MB/s]

# %%
# !ls
# Out:
# dogs-vs-cats.zip  kaggle.json  sample_data

# %%
from zipfile import ZipFile

dataset = "/content/dogs-vs-cats.zip"

with ZipFile(dataset, "r") as zip:
  zip.extractall()
  print("The dataset has been extracted")
# Out:
# The dataset has been extracted

# %%
from zipfile import ZipFile

dataset2 = "/content/train.zip"

with ZipFile(dataset2, "r") as zip:
  zip.extractall()
  print("The training data has been extracted")
# Out:
# The training data has been extracted

# %%
# Counting the no of files in train data
import os

path, directory, files = next(os.walk("/content/train"))

file_count = len(files)

print("Total no of files in Train Data are :- ", file_count)
# Out:
# Total no of files in Train Data are :-  25000

# %%
file_name = os.listdir("/content/train")
print(file_name)
# Out:
# ['cat.8324.jpg', 'cat.11730.jpg', 'dog.10296.jpg', 'cat.4024.jpg', 'dog.138.jpg', 'dog.9114.jpg', 'cat.9052.jpg', 'cat.11987.jpg', 'dog.10130.jpg', 'cat.4165.jpg', 'cat.3562.jpg', 'dog.5038.jpg', 'dog.10633.jpg', 'cat.3398.jpg', 'cat.7371.jpg', 'cat.11991.jpg', 'cat.1638.jpg', 'cat.4416.jpg', 'cat.5712.jpg', 'cat.10262.jpg', 'cat.1433.jpg', 'cat.8496.jpg', 'cat.10982.jpg', 'cat.9263.jpg', 'dog.6443.jpg', 'dog.8768.jpg', 'dog.640.jpg', 'dog.12309.jpg', 'cat.3085.jpg', 'dog.8557.jpg', 'dog.5144.jpg', 'cat.9861.jpg', 'cat.8236.jpg', 'dog.240.jpg', 'dog.6998.jpg', 'dog.4677.jpg', 'cat.8844.jpg', 'dog.10241.jpg', 'dog.8143.jpg', 'dog.11828.jpg', 'dog.8551.jpg', 'cat.4571.jpg', 'cat.10242.jpg', 'cat.286.jpg', 'cat.5945.jpg', 'cat.3499.jpg', 'cat.7120.jpg', 'dog.10433.jpg', 'dog.5694.jpg', 'cat.5777.jpg', 'cat.9813.jpg', 'cat.1211.jpg', 'cat.9834.jpg', 'dog.6836.jpg', 'cat.10901.jpg', 'dog.6620.jpg', 'cat.2079.jpg', 'cat.5827.jpg', 'cat.8644.jpg', 'cat.8961.jpg', 'cat.8704.jpg', 'cat.12258.jpg', 'dog.751.jpg', 'cat.4926.jpg', 'dog.558.jpg', 'cat.2416.jpg', 'cat.8060.jpg', 'cat.2371.jpg', 'cat.8544.jpg', 'cat.4786.jpg', 'dog.1775.jpg', 'dog.690.jpg', 'cat.142.jpg', 'dog.5365.jpg', 'dog.354.jpg', 'cat.11903.jpg', 'cat.8308.jpg', 'dog.2970.jpg', 'dog.1509.jpg', 'cat.8181.jpg', 'cat.1928.jpg', 'dog.275.jpg', 'dog.10049.jpg', 'dog.10920.jpg', 'cat.4476.jpg', 'cat.3518.jpg', 'dog.6724.jpg', 'cat.12100.jpg', 'dog.12410.jpg', 'cat.2250.jpg', 'dog.8046.jpg', 'dog.6565.jpg', 'cat.2255.jpg', 'cat.6340.jpg', 'cat.6882.jpg', 'dog.11731.jpg', 'dog.10939.jpg', 'dog.7303.jpg', 'cat.4186.jpg', 'cat.11201.jpg', 'cat.5907.jpg', 'cat.7967.jpg', 'cat.3749.jpg', 'cat.266.jpg', 'dog.6299.jpg', 'dog.5158.jpg', 'dog.4891.jpg', 'cat.9982.jpg', 'dog.7140.jpg', 'cat.5153.jpg', 'cat.12271.jpg', 'dog.5843.jpg', 'cat.3396.jpg', 'dog.8083.jpg', 'dog.3577.jpg', 'cat.3354.jpg', 'cat.5307.jpg', 'dog.6043.jpg', 'cat.6195.jpg', 'cat.807.jpg', 'dog.3778.jpg', 'cat.6599.jpg', 'dog.3310.jpg', 'cat.3461.jpg', 'dog.11309.jpg', 'cat.3057.jpg', 'cat.11079.jpg', 'dog.11619.jpg', 'dog.3802.jpg', 'cat.7990.jpg', 'cat.6165.jpg', 'dog.9153.jpg', 'dog.4454.jpg', 'dog.3718.jpg', 'cat.11189.jpg', 'cat.8274.jpg', 'cat.4568.jpg', 'dog.5328.jpg', 'cat.10345.jpg', 'dog.7141.jpg', 'dog.9853.jpg', 'dog.4678.jpg', 'cat.7319.jpg', 'cat.9370.jpg', 'dog.11322.jpg', 'dog.10795.jpg', 'cat.6279.jpg', 'dog.5039.jpg', 'cat.7095.jpg', 'cat.6412.jpg', 'dog.7773.jpg', 'dog.10650.jpg', 'cat.2793.jpg', 'cat.2541.jpg', 'dog.6092.jpg', 'dog.9727.jpg', 'dog.5678.jpg', 'cat.867.jpg', 'dog.741.jpg', 'dog.7846.jpg', 'dog.5095.jpg', 'cat.8089.jpg', 'cat.8403.jpg', 'dog.10286.jpg', 'dog.6824.jpg', 'dog.5326.jpg', 'cat.6185.jpg', 'cat.6252.jpg', 'cat.2829.jpg', 'dog.11611.jpg', 'cat.5143.jpg', 'dog.1351.jpg', 'cat.6540.jpg', 'dog.6323.jpg', 'dog.5422.jpg', 'dog.12163.jpg', 'dog.6182.jpg', 'dog.1479.jpg', 'cat.5472.jpg', 'dog.11234.jpg', 'dog.9861.jpg', 'cat.4718.jpg', 'dog.9847.jpg', 'dog.9505.jpg', 'dog.5182.jpg', 'dog.7341.jpg', 'cat.12162.jpg', 'cat.5823.jpg', 'cat.2838.jpg', 'cat.3474.jpg', 'dog.11476.jpg', 'cat.1326.jpg', 'dog.2103.jpg', 'dog.1836.jpg', 'cat.9525.jpg', 'dog.717.jpg', 'dog.8155.jpg', 'cat.4497.jpg', 'dog.2744.jpg', 'cat.3419.jpg', 'cat.7921.jpg', 'dog.8443.jpg', 'cat.5132.jpg', 'dog.5117.jpg', 'dog.6603.jpg', 'cat.3797.jpg', 'cat.4274.jpg', 'cat.4289.jpg', 'cat.2835.jpg', 'dog.64.jpg', 'cat.9939.jpg', 'cat.935.jpg', 'dog.1257.jpg', 'cat.7795.jpg', 'cat.9406.jpg', 'cat.3660.jpg', 'cat.9350.jpg', 'dog.9006.jpg', 'cat.6518.jpg', 'dog.2844.jpg', 'dog.7031.jpg', 'dog.6447.jpg', 'cat.4028.jpg', 'cat.11236.jpg', 'cat.11324.jpg', 'dog.10249.jpg', 'cat.9858.jpg', 'dog.2853.jpg', 'dog.6938.jpg', 'dog.8316.jpg', 'cat.5809.jpg', 'dog.1385.jpg', 'cat.1477.jpg', 'cat.6257.jpg', 'dog.180.jpg', 'dog.7618.jpg', 'dog.5309.jpg', 'cat.4639.jpg', 'dog.2054.jpg', 'cat.6281.jpg', 'dog.4246.jpg', 'dog.2433.jpg', 'cat.193.jpg', 'cat.7872.jpg', 'cat.9733.jpg', 'cat.9348.jpg', 'cat.10032.jpg', 'dog.8567.jpg', 'dog.3929 ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from google.colab.patches import cv2_imshow

import cv2

# %%
img = mpimg.imread("/content/train/cat.8215.jpg")

# %%
img
# Out:
# array([[[ 45,  72,  37],
#         [ 50,  77,  42],
#         [ 51,  78,  43],
#         ...,
#         [143, 107,  91],
#         [144, 108,  92],
#         [145, 109,  93]],
#
#        [[ 42,  69,  34],
#         [ 47,  74,  39],
#         [ 48,  75,  40],
#         ...,
#         [142, 106,  90],
#         [142, 106,  90],
#         [141, 105,  89]],
#
#        [[ 44,  70,  35],
#         [ 48,  74,  39],
#         [ 49,  75,  40],
#         ...,
#         [140, 104,  88],
#         [138, 102,  86],
#         [136, 100,  84]],
#
#        ...,
#
#        [[ 30,  16,  13],
#         [ 30,  16,  13],
#         [ 29,  18,  12],
#         ...,
#         [ 69,  41,  29],
#         [ 71,  43,  31],
#         [ 74,  46,  34]],
#
#        [[ 28,  14,  11],
#         [ 29,  15,  12],
#         [ 28,  17,  11],
#         ...,
#         [ 68,  40,  28],
#         [ 71,  43,  31],
#         [ 74,  46,  34]],
#
#        [[ 27,  13,  10],
#         [ 28,  14,  11],
#         [ 27,  16,  10],
#         ...,
#         [ 68,  40,  28],
#         [ 71,  43,  31],
#         [ 73,  45,  33]]], dtype=uint8)

# %%
file_name = os.listdir("/content/train")

for i in range(5):
  name = file_name[i]
  print(name[0:3])
# Out:
# cat
# cat
# dog
# cat
# dog

# %%
dog_count = 0
cat_count = 0

for i in file_name:
  name = i[0:3]

  if name=="dog":
    dog_count +=1
  elif name=="cat":
    cat_count +=1

print("No of dogs are :- ", dog_count)
print("No of cats are :- ", cat_count)
# Out:
# No of dogs are :-  12500
# No of cats are :-  12500

# %%
# Making directory

os.mkdir("/content/image_resized")

# %%
original_folder = "/content/train/"
image_resized = "/content/image_resized/"

for i in range(2000):
  filename = os.listdir(original_folder)[i]
  img_path = original_folder+filename

  # Now you can resize the image :-
  img = Image.open(img_path)
  img = img.resize((224,224))
  img = img.convert("RGB")

  newimagepath = image_resized + filename
  img.save(newimagepath)

# %%
# checking the resized image
img = mpimg.imread("/content/image_resized/cat.1001.jpg")

# %%
img
# Out:
# array([[[ 57,  54,  21],
#         [ 55,  52,  19],
#         [ 56,  50,  18],
#         ...,
#         [ 37,  29,  16],
#         [ 31,  19,   7],
#         [ 38,  26,  14]],
#
#        [[ 54,  51,  18],
#         [ 54,  49,  17],
#         [ 53,  47,  15],
#         ...,
#         [ 37,  29,  16],
#         [ 34,  24,  12],
#         [ 39,  29,  17]],
#
#        [[ 52,  47,  15],
#         [ 50,  45,  13],
#         [ 50,  44,  12],
#         ...,
#         [ 64,  58,  46],
#         [ 61,  55,  43],
#         [ 66,  58,  47]],
#
#        ...,
#
#        [[ 46, 169, 106],
#         [ 49, 169, 107],
#         [ 50, 168, 107],
#         ...,
#         [ 27, 154, 101],
#         [ 23, 154, 100],
#         [ 19, 154,  98]],
#
#        [[ 46, 166, 104],
#         [ 46, 166, 104],
#         [ 48, 166, 105],
#         ...,
#         [ 32, 156, 106],
#         [ 26, 153, 102],
#         [ 23, 151, 100]],
#
#        [[ 43, 163, 101],
#         [ 44, 164, 102],
#         [ 48, 164, 103],
#         ...,
#         [ 37, 161, 111],
#         [ 34, 158, 108],
#         [ 31, 158, 107]]], dtype=uint8)

# %%
# Now let's create labels for dog and cat

# cat 0
# dog 1

filename = os.listdir("/content/image_resized")

labels = []

for i in filename:
  name = i[0:3]

  if name=="dog":
    labels.append(1)
  elif name=="cat":
    labels.append(0)

# %%
print(filename[0:5])
print(len(filename))
# Out:
# ['cat.8324.jpg', 'cat.11730.jpg', 'dog.10296.jpg', 'cat.4024.jpg', 'dog.138.jpg']
# 2000

# %%
print(labels[0:5])
print(len(labels))
# Out:
# [0, 0, 1, 0, 1]
# 2000

# %%
# Counting no of dog images and cat images.

filename = os.listdir("/content/image_resized")

dog_count = 0
cat_count = 0

for i in filename:
  name = i[0:3]

  if name=="dog":
    dog_count +=1
  elif name=="cat":
    cat_count +=1

print("The no of dog images in resized folder is :- ", dog_count)
print("The no of cat images in resized folder is :- ", cat_count)
# Out:
# The no of dog images in resized folder is :-  1009
# The no of cat images in resized folder is :-  991

# %%
# Converting the images to numpy array before feeding them to our DL

resized_folder = os.listdir("/content/image_resized")
print(resized_folder)
# Out:
# ['cat.8324.jpg', 'cat.11730.jpg', 'dog.10296.jpg', 'cat.4024.jpg', 'dog.138.jpg', 'dog.9114.jpg', 'cat.9052.jpg', 'cat.11987.jpg', 'dog.10130.jpg', 'cat.4165.jpg', 'cat.3562.jpg', 'dog.5038.jpg', 'dog.10633.jpg', 'cat.3398.jpg', 'cat.7371.jpg', 'cat.11991.jpg', 'cat.1638.jpg', 'cat.4416.jpg', 'cat.5712.jpg', 'cat.10262.jpg', 'cat.1433.jpg', 'cat.8496.jpg', 'cat.10982.jpg', 'cat.9263.jpg', 'dog.6443.jpg', 'dog.8768.jpg', 'dog.640.jpg', 'dog.12309.jpg', 'cat.3085.jpg', 'dog.8557.jpg', 'dog.5144.jpg', 'cat.9861.jpg', 'cat.8236.jpg', 'dog.240.jpg', 'dog.6998.jpg', 'dog.4677.jpg', 'cat.8844.jpg', 'dog.10241.jpg', 'dog.8143.jpg', 'dog.11828.jpg', 'dog.8551.jpg', 'cat.4571.jpg', 'cat.10242.jpg', 'cat.286.jpg', 'cat.5945.jpg', 'cat.3499.jpg', 'cat.7120.jpg', 'dog.10433.jpg', 'dog.5694.jpg', 'cat.5777.jpg', 'cat.9813.jpg', 'cat.1211.jpg', 'cat.9834.jpg', 'dog.6836.jpg', 'cat.10901.jpg', 'dog.6620.jpg', 'cat.2079.jpg', 'cat.5827.jpg', 'cat.8644.jpg', 'cat.8961.jpg', 'cat.8704.jpg', 'cat.12258.jpg', 'dog.751.jpg', 'cat.4926.jpg', 'dog.558.jpg', 'cat.2416.jpg', 'cat.8060.jpg', 'cat.2371.jpg', 'cat.8544.jpg', 'cat.4786.jpg', 'dog.1775.jpg', 'dog.690.jpg', 'cat.142.jpg', 'dog.5365.jpg', 'dog.354.jpg', 'cat.11903.jpg', 'cat.8308.jpg', 'dog.2970.jpg', 'dog.1509.jpg', 'cat.8181.jpg', 'cat.1928.jpg', 'dog.275.jpg', 'dog.10049.jpg', 'dog.10920.jpg', 'cat.4476.jpg', 'cat.3518.jpg', 'dog.6724.jpg', 'cat.12100.jpg', 'dog.12410.jpg', 'cat.2250.jpg', 'dog.8046.jpg', 'dog.6565.jpg', 'cat.2255.jpg', 'cat.6340.jpg', 'cat.6882.jpg', 'dog.11731.jpg', 'dog.10939.jpg', 'dog.7303.jpg', 'cat.4186.jpg', 'cat.11201.jpg', 'cat.5907.jpg', 'cat.7967.jpg', 'cat.3749.jpg', 'cat.266.jpg', 'dog.6299.jpg', 'dog.5158.jpg', 'dog.4891.jpg', 'cat.9982.jpg', 'dog.7140.jpg', 'cat.5153.jpg', 'cat.12271.jpg', 'dog.5843.jpg', 'cat.3396.jpg', 'dog.8083.jpg', 'dog.3577.jpg', 'cat.3354.jpg', 'cat.5307.jpg', 'dog.6043.jpg', 'cat.6195.jpg', 'cat.807.jpg', 'dog.3778.jpg', 'cat.6599.jpg', 'dog.3310.jpg', 'cat.3461.jpg', 'dog.11309.jpg', 'cat.3057.jpg', 'cat.11079.jpg', 'dog.11619.jpg', 'dog.3802.jpg', 'cat.7990.jpg', 'cat.6165.jpg', 'dog.9153.jpg', 'dog.4454.jpg', 'dog.3718.jpg', 'cat.11189.jpg', 'cat.8274.jpg', 'cat.4568.jpg', 'dog.5328.jpg', 'cat.10345.jpg', 'dog.7141.jpg', 'dog.9853.jpg', 'dog.4678.jpg', 'cat.7319.jpg', 'cat.9370.jpg', 'dog.11322.jpg', 'dog.10795.jpg', 'cat.6279.jpg', 'dog.5039.jpg', 'cat.7095.jpg', 'cat.6412.jpg', 'dog.7773.jpg', 'dog.10650.jpg', 'cat.2793.jpg', 'cat.2541.jpg', 'dog.6092.jpg', 'dog.9727.jpg', 'dog.5678.jpg', 'cat.867.jpg', 'dog.741.jpg', 'dog.7846.jpg', 'dog.5095.jpg', 'cat.8089.jpg', 'cat.8403.jpg', 'dog.10286.jpg', 'dog.6824.jpg', 'dog.5326.jpg', 'cat.6185.jpg', 'cat.6252.jpg', 'cat.2829.jpg', 'dog.11611.jpg', 'cat.5143.jpg', 'dog.1351.jpg', 'cat.6540.jpg', 'dog.6323.jpg', 'dog.5422.jpg', 'dog.12163.jpg', 'dog.6182.jpg', 'dog.1479.jpg', 'cat.5472.jpg', 'dog.11234.jpg', 'dog.9861.jpg', 'cat.4718.jpg', 'dog.9847.jpg', 'dog.9505.jpg', 'dog.5182.jpg', 'dog.7341.jpg', 'cat.12162.jpg', 'cat.5823.jpg', 'cat.2838.jpg', 'cat.3474.jpg', 'dog.11476.jpg', 'cat.1326.jpg', 'dog.2103.jpg', 'dog.1836.jpg', 'cat.9525.jpg', 'dog.717.jpg', 'dog.8155.jpg', 'cat.4497.jpg', 'dog.2744.jpg', 'cat.3419.jpg', 'cat.7921.jpg', 'dog.8443.jpg', 'cat.5132.jpg', 'dog.5117.jpg', 'dog.6603.jpg', 'cat.3797.jpg', 'cat.4274.jpg', 'cat.4289.jpg', 'cat.2835.jpg', 'dog.64.jpg', 'cat.9939.jpg', 'cat.935.jpg', 'dog.1257.jpg', 'cat.7795.jpg', 'cat.9406.jpg', 'cat.3660.jpg', 'cat.9350.jpg', 'dog.9006.jpg', 'cat.6518.jpg', 'dog.2844.jpg', 'dog.7031.jpg', 'dog.6447.jpg', 'cat.4028.jpg', 'cat.11236.jpg', 'cat.11324.jpg', 'dog.10249.jpg', 'cat.9858.jpg', 'dog.2853.jpg', 'dog.6938.jpg', 'dog.8316.jpg', 'cat.5809.jpg', 'dog.1385.jpg', 'cat.1477.jpg', 'cat.6257.jpg', 'dog.180.jpg', 'dog.7618.jpg', 'dog.5309.jpg', 'cat.4639.jpg', 'dog.2054.jpg', 'cat.6281.jpg', 'dog.4246.jpg', 'dog.2433.jpg', 'cat.193.jpg', 'cat.7872.jpg', 'cat.9733.jpg', 'cat.9348.jpg', 'cat.10032.jpg', 'dog.8567.jpg', 'dog.3929 ...

# %%
img_array = []

for i in resized_folder:
  img_path = "/content/image_resized/"+i
  img = cv2.imread(img_path)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  img_array.append(img)

img_array = np.array(img_array)

# %%
img_array
# Out:
# array([[[[ 61,  51,  50],
#          [ 59,  49,  48],
#          [ 57,  47,  46],
#          ...,
#          [109,  88,  83],
#          [109,  88,  83],
#          [109,  88,  83]],
#
#         [[ 60,  50,  49],
#          [ 60,  50,  49],
#          [ 60,  50,  49],
#          ...,
#          [109,  88,  83],
#          [109,  88,  83],
#          [109,  88,  83]],
#
#         [[ 56,  46,  45],
#          [ 58,  48,  47],
#          [ 61,  51,  50],
#          ...,
#          [110,  89,  84],
#          [110,  89,  86],
#          [110,  89,  86]],
#
#         ...,
#
#         [[152, 151, 149],
#          [156, 155, 153],
#          [155, 154, 152],
#          ...,
#          [ 81,  62,  48],
#          [ 81,  59,  46],
#          [ 80,  58,  45]],
#
#         [[141, 140, 138],
#          [146, 145, 143],
#          [147, 146, 144],
#          ...,
#          [ 81,  62,  48],
#          [ 81,  59,  46],
#          [ 80,  58,  45]],
#
#         [[136, 135, 133],
#          [141, 140, 138],
#          [144, 143, 141],
#          ...,
#          [ 80,  61,  47],
#          [ 80,  58,  45],
#          [ 79,  57,  44]]],
#
#
#        [[[ 69,  84, 115],
#          [ 69,  84, 115],
#          [ 70,  87, 117],
#          ...,
#          [107, 127, 152],
#          [107, 127, 152],
#          [107, 127, 152]],
#
#         [[ 69,  84, 115],
#          [ 69,  84, 115],
#          [ 70,  87, 117],
#          ...,
#          [106, 126, 151],
#          [106, 126, 151],
#          [107, 127, 152]],
#
#         [[ 68,  85, 113],
#          [ 68,  85, 113],
#          [ 70,  87, 115],
#          ...,
#          [106, 126, 151],
#          [106, 126, 151],
#          [106, 126, 151]],
#
#         ...,
#
#         [[ 83,  77,  79],
#          [ 86,  80,  82],
#          [ 89,  83,  85],
#          ...,
#          [112, 102, 101],
#          [108,  98,  97],
#          [104,  94,  93]],
#
#         [[ 82,  76,  78],
#          [ 85,  79,  81],
#          [ 89,  83,  85],
#          ...,
#          [110, 100,  99],
#          [106,  96,  95],
#          [103,  93,  92]],
#
#         [[ 82,  76,  78],
#          [ 85,  79,  81],
#          [ 88,  82,  84],
#          ...,
#          [109,  99,  98],
#          [106,  96,  95],
#          [103,  93,  92]]],
#
#
#        [[[200, 197, 180],
#          [193, 192, 174],
#          [175, 174, 156],
#          ...,
#          [138, 135, 116],
#          [143, 136, 117],
#          [145, 139, 117]],
#
#         [[191, 188, 171],
#          [194, 191, 174],
#          [180, 179, 161],
#          ...,
#          [138, 135, 116],
#          [143, 136, 117],
#          [145, 139, 117]],
#
#         [[192, 186, 170],
#          [204, 201, 184],
#          [197, 196, 178],
#          ...,
#          [138, 135, 116],
#          [144, 137, 118],
#          [146, 140, 118]],
#
#         ...,
#
#         [[226, 228, 204],
#          [231, 233, 209],
#          [235, 235, 211],
#          ...,
#          [ 95,  97,  75],
#          [ 96,  98,  76],
#          [103, 105,  83]],
#
#         [[220, 224, 199],
#          [227, 229, 205],
#          [234, 234, 210],
#          ...,
#          [ 96,  98,  76],
#          [ 98, 100,  78],
#          [ 97,  99,  77]],
#
#         [[218, 222, 197],
#          [224, 228, 203],
#          [233, 233, 209],
#          ...,
#          [121, 123, 101],
#          [116, 118,  96],
#          [ 97,  99,  77]]],
#
#
#        ...,
#
#
#        [[[ 47,  74,  85],
#          [ 49,  76,  87],
#          [ 54,  78,  90],
#          ...,
#          [ 92,  92,  92],
#          [ 90,  90,  90],
#          [ 89,  89,  89]],
#
#         [[ 52,  79,  90],
#          [ 53,  80,  91],
#          [ 55,  79,  91],
#          ...,
#          [ 93,  93,  93],
#          [ 91,  91,  91],
#          [ 89,  89,  89]],
#
#         [[ 57,  84,  95],
#          [ 56,  83,  94],
#          [ 57,  81,  93],
#          ...,
#          [ 93,  93,  93],
#          [ 91,  91,  91],
#          [ 90,  90,  90]],
#
#         ...,
#
#         [[ 21,  12,   7],
#          [ 21,  12,   7],
#          [ 21,  12,   7],
#          ...,
#          [ 74, 106, 127],
#          [ 76, 108, 129],
#          [ 76, 108, 129]],
#
#         [[ 22,  13,   8],
#          [ 22,  13,   8],
#          [ 21,  12,   7],
#          ...,
#          [ 74, 105, 126],
#          [ 75, 106, 127],
#          [ 74, 105, 126]],
#
#         [[ 23,  14,   9],
#          [ 23,  14,   9],
#          [ 22,  13,   8],
#          ...,
#          [ 73, 104, 125],
#          [ 74, 105, 126],
#          [ 72, 103, 124]]],
#
#
#        [[[103,  98,  92],
#          [105, 100,  94],
#          [107, 102,  96],
#          ...,
#          [ 54,  46,   0],
#          [ 58,  47,   1],
#          [ 58,  47,   1]],
#
#         [[104,  99,  93],
#          [105, 100,  94],
#          [107, 102,  96],
#          ...,
#          [ 54,  45,   2],
#          [ 56,  45,   0],
#          [ 56,  45,   0]],
#
#         [[106, 101,  95],
#          [106, 101,  95],
#          [106, 101,  95],
#          ...,
#          [ 54,  45,   6],
#          [ 53,  44,   3],
#          [ 53,  44,   3]],
#
#         ...,
#
#         [[ 19,  14,  11],
#          [ 19,  14,  11],
#          [ 18,  13,  10],
#          ...,
#          [ 51,  43,  20],
#          [ 53,  45,  22],
#          [ 54,  46,  23]],
#
#         [[ 19,  14,  11],
#          [ 19,  14,  11],
#          [ 18,  13,  10],
#          ...,
#          [ 53,  45,  22],
#          [ 53,  45,  22],
#          [ 54,  46,  23]],
#
#         [[ 17,  12,   9],
#          [ 17,  12,   9],
#          [ 17,  12,   9],
#          ...,
#          [ 54,  46,  23],
#          [ 54,  46,  23],
#          [ 53,  45,  22]]],
#
#
#        [[[182, 181, 177],
#          [181, 180, 176],
#          [180, 179, 175],
#          ...,
#          [187, 183, 171],
#          [188, 184, 172],
#          [189, 185, 173]],
#
#         [[182, 181, 177],
#          [181, 180, 176],
#          [180, 179, 175],
#          ...,
#          [185, 181, 169],
#          [186, 182, 170],
#          [187, 183, 171]],
#
#         [[182, 181, 177],
#          [181, 180, 176],
#          [180, 179, 175],
#          ...,
#          [184, 180, 168],
#          [185, 181, 169],
#          [185, 181, 169]],
#
#         ...,
#
#         [[236, 236, 248],
#          [235, 235, 247],
#          [234, 234, 246],
#          ...,
#          [189, 187, 174],
#          [188, 186, 173],
#          [188, 186, 173]],
#
#         [[235, 235, 247],
#          [235, 235, 247],
#          [234, 234, 246],
#          ...,
#          [188, 186, 173],
#          [188, 186, 173],
#          [188, 186, 173]],
#
#         [[235, 235, 247],
#          [235, 235, 247],
#          [234, 234, 246],
#          ...,
#          [188, 186, 173],
#          [188, 186, 173],
#          [188, 186, 173]]]], dtype=uint8)

# %%
img_array.shape
# Out:
# (2000, 224, 224, 3)

# %%
# splitting into labes (X&Y)

X = img_array
Y = np.asarray(labels)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=2, stratify=Y)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (2000, 224, 224, 3) (1600, 224, 224, 3) (400, 224, 224, 3)

# %%
# Scaling the data
X_train = X_train/255
X_test = X_test/255

# %%
X_train
# Out:
# array([[[[0.65098039, 0.67843137, 0.74901961],
#          [0.69411765, 0.72156863, 0.79215686],
#          [0.72941176, 0.75686275, 0.82745098],
#          ...,
#          [0.59607843, 0.60784314, 0.62745098],
#          [0.58823529, 0.60392157, 0.61568627],
#          [0.58039216, 0.59607843, 0.60784314]],
#
#         [[0.65882353, 0.68627451, 0.75686275],
#          [0.70196078, 0.72941176, 0.8       ],
#          [0.7372549 , 0.76470588, 0.83529412],
#          ...,
#          [0.90980392, 0.92156863, 0.94117647],
#          [0.90196078, 0.91764706, 0.92941176],
#          [0.89411765, 0.90980392, 0.92156863]],
#
#         [[0.67058824, 0.69803922, 0.76078431],
#          [0.70980392, 0.7372549 , 0.8       ],
#          [0.74117647, 0.76862745, 0.83137255],
#          ...,
#          [0.98823529, 1.        , 1.        ],
#          [0.97647059, 0.99215686, 1.        ],
#          [0.96470588, 0.98039216, 0.99215686]],
#
#         ...,
#
#         [[0.38823529, 0.41176471, 0.41176471],
#          [0.37254902, 0.39607843, 0.39607843],
#          [0.35686275, 0.38039216, 0.38039216],
#          ...,
#          [0.65098039, 0.70588235, 0.63921569],
#          [0.67843137, 0.73333333, 0.66666667],
#          [0.70588235, 0.76078431, 0.69411765]],
#
#         [[0.34901961, 0.38039216, 0.38823529],
#          [0.3372549 , 0.36862745, 0.37647059],
#          [0.33333333, 0.35686275, 0.35686275],
#          ...,
#          [0.66666667, 0.72156863, 0.65490196],
#          [0.68235294, 0.7372549 , 0.67058824],
#          [0.69411765, 0.74901961, 0.68235294]],
#
#         [[0.32941176, 0.36078431, 0.36862745],
#          [0.32156863, 0.35294118, 0.36078431],
#          [0.31764706, 0.34117647, 0.34117647],
#          ...,
#          [0.68235294, 0.7372549 , 0.67058824],
#          [0.68627451, 0.74117647, 0.6745098 ],
#          [0.68627451, 0.74117647, 0.6745098 ]]],
#
#
#        [[[0.60784314, 0.56470588, 0.44705882],
#          [0.60392157, 0.56078431, 0.44313725],
#          [0.60392157, 0.56078431, 0.44313725],
#          ...,
#          [0.03921569, 0.22352941, 0.3254902 ],
#          [0.04313725, 0.22745098, 0.34509804],
#          [0.05490196, 0.23529412, 0.36470588]],
#
#         [[0.60784314, 0.56470588, 0.44705882],
#          [0.60392157, 0.56078431, 0.44313725],
#          [0.60392157, 0.56078431, 0.44313725],
#          ...,
#          [0.04705882, 0.22745098, 0.32156863],
#          [0.05098039, 0.22745098, 0.34117647],
#          [0.0627451 , 0.23921569, 0.35294118]],
#
#         [[0.60784314, 0.56470588, 0.44705882],
#          [0.60392157, 0.56078431, 0.44313725],
#          [0.60392157, 0.56078431, 0.44313725],
#          ...,
#          [0.05882353, 0.22745098, 0.30196078],
#          [0.05490196, 0.21960784, 0.31372549],
#          [0.0627451 , 0.22745098, 0.32156863]],
#
#         ...,
#
#         [[0.47058824, 0.43921569, 0.35686275],
#          [0.4745098 , 0.44313725, 0.36078431],
#          [0.4745098 , 0.44313725, 0.36078431],
#          ...,
#          [0.04705882, 0.19607843, 0.23137255],
#          [0.04705882, 0.19607843, 0.23137255],
#          [0.04313725, 0.19215686, 0.22745098]],
#
#         [[0.47058824, 0.43921569, 0.35686275],
#          [0.47058824, 0.43921569, 0.35686275],
#          [0.4745098 , 0.44313725, 0.36078431],
#          ...,
#          [0.04313725, 0.19215686, 0.22745098],
#          [0.04313725, 0.19215686, 0.22745098],
#          [0.03921569, 0.18823529, 0.22352941]],
#
#         [[0.47058824, 0.43921569, 0.35686275],
#          [0.47058824, 0.43921569, 0.35686275],
#          [0.47058824, 0.43921569, 0.35686275],
#          ...,
#          [0.03921569, 0.18823529, 0.22352941],
#          [0.03921569, 0.18823529, 0.22352941],
#          [0.03921569, 0.18823529, 0.22352941]]],
#
#
#        [[[0.51764706, 0.43137255, 0.28627451],
#          [0.41960784, 0.33333333, 0.18823529],
#          [0.36078431, 0.2745098 , 0.12941176],
#          ...,
#          [0.3372549 , 0.23137255, 0.11372549],
#          [0.35686275, 0.25882353, 0.1372549 ],
#          [0.37254902, 0.2745098 , 0.15294118]],
#
#         [[0.50196078, 0.41568627, 0.27058824],
#          [0.41568627, 0.32941176, 0.18431373],
#          [0.35686275, 0.27058824, 0.1254902 ],
#          ...,
#          [0.34901961, 0.24313725, 0.1254902 ],
#          [0.38431373, 0.28627451, 0.16470588],
#          [0.40784314, 0.30980392, 0.18823529]],
#
#         [[0.45490196, 0.36862745, 0.22352941],
#          [0.40392157, 0.31764706, 0.17254902],
#          [0.36078431, 0.2745098 , 0.12941176],
#          ...,
#          [0.36862745, 0.2627451 , 0.14509804],
#          [0.40784314, 0.30980392, 0.18823529],
#          [0.42745098, 0.32941176, 0.20784314]],
#
#         ...,
#
#         [[0.23529412, 0.18431373, 0.11764706],
#          [0.25490196, 0.20392157, 0.12941176],
#          [0.20784314, 0.16470588, 0.07843137],
#          ...,
#          [0.80392157, 0.73333333, 0.57647059],
#          [0.8       , 0.74509804, 0.55294118],
#          [0.78823529, 0.74509804, 0.53333333]],
#
#         [[0.23921569, 0.18823529, 0.11372549],
#          [0.2627451 , 0.21176471, 0.1372549 ],
#          [0.23921569, 0.19607843, 0.10980392],
#          ...,
#          [0.8       , 0.72941176, 0.58039216],
#          [0.79607843, 0.74117647, 0.55686275],
#          [0.78823529, 0.7372549 , 0.53333333]],
#
#         [[0.21176471, 0.16078431, 0.08627451],
#          [0.23137255, 0.18431373, 0.09803922],
#          [0.2627451 , 0.21960784, 0.13333333],
#          ...,
#          [0.8       , 0.72941176, 0.58039216],
#          [0.8       , 0.73333333, 0.55294118],
#          [0.78431373, 0.73333333, 0.52941176]]],
#
#
#        ...,
#
#
#        [[[0.72156863, 0.71764706, 0.63921569],
#          [0.73333333, 0.72941176, 0.65098039],
#          [0.74509804, 0.74117647, 0.6627451 ],
#          ...,
#          [0.74509804, 0.71764706, 0.64705882],
#          [0.73333333, 0.70588235, 0.63529412],
#          [0.7254902 , 0.69803922, 0.62745098]],
#
#         [[0.7254902 , 0.72156863, 0.64313725],
#          [0.7372549 , 0.73333333, 0.65490196],
#          [0.74901961, 0.74509804, 0.66666667],
#          ...,
#          [0.75294118, 0.7254902 , 0.65490196],
#          [0.74509804, 0.71764706, 0.64705882],
#          [0.74117647, 0.71372549, 0.64313725]],
#
#         [[0.73333333, 0.72941176, 0.65098039],
#          [0.74117647, 0.7372549 , 0.65882353],
#          [0.75294118, 0.74901961, 0.67058824],
#          ...,
#          [0.75686275, 0.72941176, 0.65882353],
#          [0.75686275, 0.72941176, 0.65882353],
#          [0.75686275, 0.72941176, 0.65882353]],
#
#         ...,
#
#         [[0.5254902 , 0.44705882, 0.23921569],
#          [0.53333333, 0.45490196, 0.24705882],
#          [0.5254902 , 0.44705882, 0.24705882],
#          ...,
#          [0.68235294, 0.6627451 , 0.58823529],
#          [0.67843137, 0.65882353, 0.58431373],
#          [0.67843137, 0.65882353, 0.58431373]],
#
#         [[0.52156863, 0.44313725, 0.23529412],
#          [0.54901961, 0.47058824, 0.2627451 ],
#          [0.55294118, 0.4745098 , 0.2745098 ],
#          ...,
#          [0.67843137, 0.65882353, 0.58431373],
#          [0.6745098 , 0.65490196, 0.58039216],
#          [0.6745098 , 0.65490196, 0.58039216]],
#
#         [[0.50980392, 0.43137255, 0.22352941],
#          [0.54901961, 0.47058824, 0.2627451 ],
#          [0.57254902, 0.49411765, 0.29411765],
#          ...,
#          [0.67843137, 0.65882353, 0.58431373],
#          [0.6745098 , 0.65490196, 0.58039216],
#          [0.6745098 , 0.65490196, 0.58039216]]],
#
#
#        [[[0.4       , 0.40392157, 0.42352941],
#          [0.48627451, 0.49019608, 0.50980392],
#          [0.52156863, 0.5254902 , 0.54509804],
#          ...,
#          [0.70980392, 0.63137255, 0.63529412],
#          [0.72156863, 0.64313725, 0.64705882],
#          [0.7254902 , 0.64705882, 0.65098039]],
#
#         [[0.49803922, 0.50196078, 0.52156863],
#          [0.43921569, 0.44313725, 0.4627451 ],
#          [0.37647059, 0.38039216, 0.4       ],
#          ...,
#          [0.70588235, 0.62745098, 0.63137255],
#          [0.7254902 , 0.64705882, 0.65098039],
#          [0.73333333, 0.65490196, 0.65882353]],
#
#         [[0.29019608, 0.29411765, 0.30980392],
#          [0.23529412, 0.23921569, 0.25490196],
#          [0.22745098, 0.23137255, 0.24705882],
#          ...,
#          [0.69019608, 0.61176471, 0.61568627],
#          [0.70980392, 0.63137255, 0.63529412],
#          [0.72156863, 0.64313725, 0.64705882]],
#
#         ...,
#
#         [[0.56470588, 0.55686275, 0.50588235],
#          [0.59607843, 0.58823529, 0.5372549 ],
#          [0.4       , 0.4       , 0.35294118],
#          ...,
#          [0.39215686, 0.48235294, 0.61568627],
#          [0.45490196, 0.56078431, 0.7372549 ],
#          [0.40784314, 0.53333333, 0.7254902 ]],
#
#         [[0.50980392, 0.50196078, 0.45098039],
#          [0.50980392, 0.50196078, 0.45098039],
#          [0.45882353, 0.45098039, 0.40392157],
#          ...,
#          [0.35686275, 0.43529412, 0.57254902],
#          [0.43137255, 0.5254902 , 0.70588235],
#          [0.40784314, 0.52941176, 0.71372549]],
#
#         [[0.50588235, 0.49803922, 0.44705882],
#          [0.42745098, 0.41960784, 0.36862745],
#          [0.49411765, 0.48627451, 0.43921569],
#          ...,
#          [0.3254902 , 0.39607843, 0.5372549 ],
#          [0.39607843, 0.49019608, 0.6627451 ],
#          [0.40784314, 0.51764706, 0.70588235]]],
#
#
#        [[[0.26666667, 0.42745098, 0.16862745],
#          [0.18431373, 0.34509804, 0.07843137],
#          [0.20784314, 0.36862745, 0.10196078],
#          ...,
#          [0.21176471, 0.36862745, 0.09019608],
#          [0.18039216, 0.3372549 , 0.05098039],
#          [0.17254902, 0.32941176, 0.04313725]],
#
#         [[0.20392157, 0.36470588, 0.10588235],
#          [0.17254902, 0.33333333, 0.06666667],
#          [0.21176471, 0.37254902, 0.09803922],
#          ...,
#          [0.21568627, 0.37254902, 0.09411765],
#          [0.19215686, 0.34901961, 0.0627451 ],
#          [0.17647059, 0.33333333, 0.04705882]],
#
#         [[0.26666667, 0.42745098, 0.16078431],
#          [0.24313725, 0.40392157, 0.1372549 ],
#          [0.23137255, 0.39215686, 0.11764706],
#          ...,
#          [0.21568627, 0.37254902, 0.09411765],
#          [0.24705882, 0.39607843, 0.10980392],
#          [0.25490196, 0.40392157, 0.11764706]],
#
#         ...,
#
#         [[0.38431373, 0.36078431, 0.26666667],
#          [0.39215686, 0.36862745, 0.2745098 ],
#          [0.34117647, 0.31764706, 0.21568627],
#          ...,
#          [0.35294118, 0.4       , 0.21176471],
#          [0.34117647, 0.38823529, 0.2       ],
#          [0.36078431, 0.40784314, 0.21960784]],
#
#         [[0.38823529, 0.35686275, 0.26666667],
#          [0.39215686, 0.36078431, 0.27058824],
#          [0.3254902 , 0.29803922, 0.19607843],
#          ...,
#          [0.35294118, 0.4       , 0.21960784],
#          [0.45490196, 0.49019608, 0.31372549],
#          [0.54509804, 0.58039216, 0.40392157]],
#
#         [[0.30588235, 0.2627451 , 0.17647059],
#          [0.30196078, 0.25882353, 0.17254902],
#          [0.23921569, 0.2       , 0.10196078],
#          ...,
#          [0.48235294, 0.52941176, 0.34901961],
#          [0.52156863, 0.55686275, 0.38039216],
#          [0.43137255, 0.46666667, 0.29019608]]]])

# %% [markdown]
# ## **Building the Neural Network**

# %%
import tensorflow as tf
tf.random.set_seed(3)
from tensorflow import keras
import tensorflow_hub as hub

# %%
mobile_net_model = 'https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4'
pretrained_model = hub.KerasLayer(model, input_shape=(224,224,3), trainable=False)

# %%
num_of_classes = 2

model = keras.Sequential([pretrained_model,
                          keras.layers.Dense(num_of_classes),
                          ])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer_1 (KerasLayer)  (None, 1280)              2257984
#
#  dense (Dense)               (None, 2)                 2562
#
# =================================================================
# Total params: 2260546 (8.62 MB)
# Trainable params: 2562 (10.01 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) , metrics=["accuracy"])

# %%
model.fit(X_train, Y_train, validation_split=0.1, epochs=5)
# Out:
# Epoch 1/5
# 45/45 [==============================] - 71s 1s/step - loss: 0.2034 - accuracy: 0.9215 - val_loss: 0.1070 - val_accuracy: 0.9688
# Epoch 2/5
# 45/45 [==============================] - 61s 1s/step - loss: 0.0585 - accuracy: 0.9833 - val_loss: 0.0761 - val_accuracy: 0.9688
# Epoch 3/5
# 45/45 [==============================] - 60s 1s/step - loss: 0.0416 - accuracy: 0.9896 - val_loss: 0.0630 - val_accuracy: 0.9750
# Epoch 4/5
# 45/45 [==============================] - 61s 1s/step - loss: 0.0326 - accuracy: 0.9910 - val_loss: 0.0572 - val_accuracy: 0.9750
# Epoch 5/5
# 45/45 [==============================] - 64s 1s/step - loss: 0.0254 - accuracy: 0.9931 - val_loss: 0.0552 - val_accuracy: 0.9812

# %%
loss, accuracy = model.evaluate(X_test,Y_test)
# Out:
# 13/13 [==============================] - 13s 977ms/step - loss: 0.0501 - accuracy: 0.9750

# %% [markdown]
# ## **Building Predictive System**

# %%
input_image_path = input("Path of the image")
img = cv2.imread(input_image_path)

img # see the image

resize_img = cv2.resize(img, (224,224))
resize_img # see the image if it has been resized

resize_img = resize_img/255 # scaled

resize_img = np.reshape(resize_img, [1,224,224,3])

prediction = model.predict(resize_img)
print(prediction)

prediction_label = [np.argmax(prediction)]
print(prediction_label)

if prediction_label[0]==0:
  print("The image represents Cat")
else:
  print("The image represents dog")
# Out:
# Path of the image/content/dog.jpg
# 1/1 [==============================] - 0s 52ms/step
# [[-0.47798547  0.9785756 ]]
# [1]
# The image represents dog
